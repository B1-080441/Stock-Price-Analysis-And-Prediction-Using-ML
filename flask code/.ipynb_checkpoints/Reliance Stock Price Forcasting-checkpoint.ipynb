# %% [markdown]
# # Reliance Stock Prediction

# %% [markdown]
# ### dependent variable = Close Price

# %% [markdown]
# ### 1. Import required packages

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

import statsmodels.api as sm

from statsmodels.tsa.stattools import acf, pacf
from math import sqrt
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA
from pandas.tseries.offsets import DateOffset

# %% [markdown]
# ### 2.Read the data from the Source

# %%
stock_data = pd.read_csv('reliance_stock_data_(1990-2023).csv')
stock_data
# Out:
#              Date    Price     Open     High      Low   Volume  Change%
# 0     Jan 02 1990     7.27     7.31     7.44     7.14        0   -1.62%
# 1     Jan 03 1990     6.92     7.18     7.18     6.84        0   -4.81%
# 2     Jan 04 1990     6.50     6.24     6.58     6.24        0   -6.07%
# 3     Jan 05 1990     6.71     6.37     6.71     6.37        0    3.23%
# 4     Jan 08 1990     6.71     7.05     7.05     6.67        0    0.00%
# ...           ...      ...      ...      ...      ...      ...      ...
# 8175  Dec 11 2023  2459.05  2452.15  2467.40  2452.15  169.52K   +0.12%
# 8176  Dec 12 2023  2423.95  2458.00  2464.90  2420.25   98.11K   -1.43%
# 8177  Dec 13 2023  2433.40  2427.75  2438.00  2406.30  137.30K   +0.39%
# 8178  Dec 14 2023  2464.50  2453.00  2475.00  2442.70    3.65M   +1.28%
# 8179  Dec 15 2023  2495.20  2472.15  2499.95  2469.05  681.58K   +1.25%
#
# [8180 rows x 7 columns]

# %% [markdown]
# ### 3. Exploratory Data Analysis(EDA)

# %%
stock_data.describe()
# Out:
#              Price         Open         High          Low
# count  8180.000000  8180.000000  8180.000000  8180.000000
# mean    483.773132   484.249945   489.842656   478.173011
# std     651.354380   651.900675   658.292800   644.944153
# min       4.360000     4.320000     4.400000     4.270000
# 25%      33.980000    33.937500    34.410000    33.532500
# 50%     307.170000   306.760000   311.145000   302.550000
# 75%     483.885000   485.605000   490.867500   478.135000
# max    2619.850000  2609.000000  2630.950000  2580.000000

# %%
stock_data.columns
# Out:
# Index(['Date', ' Price', ' Open', ' High', ' Low', ' Volume', ' Change%'], dtype='object')

# %%
stock_data.isnull().sum()
# Out:
# Date        0
#  Price      0
#  Open       0
#  High       0
#  Low        0
#  Volume     0
#  Change%    0
# dtype: int64

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8180 entries, 0 to 8179
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      8180 non-null   object
#  1    Price    8180 non-null   float64
#  2    Open     8180 non-null   float64
#  3    High     8180 non-null   float64
#  4    Low      8180 non-null   float64
#  5    Volume   8180 non-null   object
#  6    Change%  8180 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 447.5+ KB

# %%
stock_data = stock_data.drop([' Open',' High',' Low',' Volume',' Change%'], axis=1)
stock_data
# Out:
#              Date    Price
# 0     Jan 02 1990     7.27
# 1     Jan 03 1990     6.92
# 2     Jan 04 1990     6.50
# 3     Jan 05 1990     6.71
# 4     Jan 08 1990     6.71
# ...           ...      ...
# 8175  Dec 11 2023  2459.05
# 8176  Dec 12 2023  2423.95
# 8177  Dec 13 2023  2433.40
# 8178  Dec 14 2023  2464.50
# 8179  Dec 15 2023  2495.20
#
# [8180 rows x 2 columns]

# %% [markdown]
# ### 4.Data Pre-processing

# %%
stock_data.set_index(pd.to_datetime(stock_data['Date']), inplace=True)  # Set 'Date' as index
stock_data.drop(columns=['Date'], inplace=True)  # Drop the 'Date' column

# %%
stock_data
# Out:
#               Price
# Date
# 1990-01-02     7.27
# 1990-01-03     6.92
# 1990-01-04     6.50
# 1990-01-05     6.71
# 1990-01-08     6.71
# ...             ...
# 2023-12-11  2459.05
# 2023-12-12  2423.95
# 2023-12-13  2433.40
# 2023-12-14  2464.50
# 2023-12-15  2495.20
#
# [8180 rows x 1 columns]

# %%
# Convert the index to datetime format
stock_data.index = pd.to_datetime(stock_data.index, format='%b %d %Y')

# Format the index as 'YYYY-MM-DD' string if needed
stock_data.index = stock_data.index.strftime('%Y-%m-%d')

# Display the updated DataFrame with the modified index
print(stock_data)
# Out:
#               Price
# Date
# 1990-01-02     7.27
# 1990-01-03     6.92
# 1990-01-04     6.50
# 1990-01-05     6.71
# 1990-01-08     6.71
# ...             ...
# 2023-12-11  2459.05
# 2023-12-12  2423.95
# 2023-12-13  2433.40
# 2023-12-14  2464.50
# 2023-12-15  2495.20
#
# [8180 rows x 1 columns]

# %%
stock_data = stock_data.rename(columns={' Price':'Price'})

# %% [markdown]
# ### Plotting of close price

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Close Prices')
plt.plot(stock_data['Price'])
plt.title('Reliance Stock closing price')
plt.show()

# %%
stock_data['Price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Distribution of the dataset

# %%
df_close = stock_data['Price']
df_close.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
dec=seasonal_decompose(stock_data.Price,period=350)
dec.plot()
plt.show()

# %%
stock_data['Price'].describe()
# Out:
# count    8180.000000
# mean      483.773132
# std       651.354380
# min         4.360000
# 25%        33.980000
# 50%       307.170000
# 75%       483.885000
# max      2619.850000
# Name: Price, dtype: float64

# %%
X = stock_data.values
split = round(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=62.403694, mean2=905.142570
# variance1=5352.210775, variance2=487964.708788

# %% [markdown]
# ## Augmented Dickey fuller test.
# ### To check Whether Data is Stationary or not

# %%
def TestStationaryPlot(stock_data):
    rol_mean = stock_data.rolling(window = 50, center = False).mean()
    rol_std = stock_data.rolling(window = 50, center = False).std()
    
    plt.plot(stock_data, color = 'blue',label = 'Original Data')
    plt.plot(rol_mean, color = 'red', label = 'Rolling Mean')
    plt.plot(rol_std, color ='black', label = 'Rolling Std')
    plt.xticks(fontsize = 10)
    plt.yticks(fontsize = 10)
    
    plt.xlabel('Time in Years', fontsize = 10)
    plt.ylabel('Closing Price', fontsize = 10)
    plt.legend(loc='best', fontsize = 10)
    plt.title('Rolling Mean & Standard Deviation', fontsize = 10)
    plt.show(block= True)

# %%
TestStationaryPlot(stock_data)

# %%
# null Hypothesis : Data is stationary
#alternate hypothesis : Data is not stationary
def TestStationaryAdfuller(stock_data, cutoff=0.01):
    stock_data_test = adfuller(stock_data, autolag='AIC')
    stock_data_test_output = pd.Series(stock_data_test[0:4], index=['Test Statistic', 'p-value', 'Lags Used', 'Number of Observations Used'])

    for key, value in stock_data_test[4].items():
        stock_data_test_output[f'Critical Value ({key})'] = value
    print(stock_data_test_output)

    if stock_data_test[1] <= cutoff:
        print("Failed to reject null hypothesis. Data is stationary")
    else:
        print("Failed to accept null hypothesis. Data is non-stationary")

# %%
TestStationaryAdfuller(stock_data)
# Out:
# Test Statistic                    1.778975
# p-value                           0.998306
# Lags Used                        37.000000
# Number of Observations Used    8142.000000
# Critical Value (1%)              -3.431153
# Critical Value (5%)              -2.861895
# Critical Value (10%)             -2.566959
# dtype: float64
# Failed to accept null hypothesis. Data is non-stationary

# %% [markdown]
# ## Transforming Data into Stationary

# %% [markdown]
# ### A) Moving Average Method

# %%
moving_avg = stock_data.rolling(30).mean()
plt.plot(stock_data)
plt.plot(moving_avg, color='red')
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.xlabel('Time (years)', fontsize = 10)
plt.ylabel('Reliance Stock Price  (in Rs.)', fontsize = 10)
plt.title('Reliance Stock Price ', fontsize = 10)
plt.show()

# %%
moving_avg_diff = stock_data - moving_avg
moving_avg_diff.head(15)
# Out:
#             Price
# Date
# 1990-01-02    NaN
# 1990-01-03    NaN
# 1990-01-04    NaN
# 1990-01-05    NaN
# 1990-01-08    NaN
# 1990-01-09    NaN
# 1990-01-10    NaN
# 1990-01-11    NaN
# 1990-01-15    NaN
# 1990-01-16    NaN
# 1990-01-17    NaN
# 1990-01-18    NaN
# 1990-01-19    NaN
# 1990-01-22    NaN
# 1990-01-23    NaN

# %%
moving_avg_diff.dropna(inplace=True)
TestStationaryPlot(moving_avg_diff)

# %%
TestStationaryAdfuller(moving_avg_diff)
# Out:
# Test Statistic                -1.222617e+01
# p-value                        1.079292e-22
# Lags Used                      3.700000e+01
# Number of Observations Used    8.113000e+03
# Critical Value (1%)           -3.431156e+00
# Critical Value (5%)           -2.861896e+00
# Critical Value (10%)          -2.566960e+00
# dtype: float64
# Failed to reject null hypothesis. Data is stationary

# %% [markdown]
# ## First Order Differencing

# %%
# Original Series
plt.plot(stock_data)
plt.title('Original Series')
plt.show()

# 1st Differencing
stock_data_first_difference = stock_data.diff()
plt.plot(stock_data_first_difference)
plt.title('1st Order Differencing')
plt.show()

# %%
stock_data_first_difference = stock_data - stock_data.shift(1)  
TestStationaryPlot(stock_data_first_difference.dropna(inplace=False))

# %%
TestStationaryAdfuller(stock_data_first_difference.dropna(inplace=False))
# Out:
# Test Statistic                -1.639167e+01
# p-value                        2.690456e-29
# Lags Used                      3.600000e+01
# Number of Observations Used    8.142000e+03
# Critical Value (1%)           -3.431153e+00
# Critical Value (5%)           -2.861895e+00
# Critical Value (10%)          -2.566959e+00
# dtype: float64
# Failed to reject null hypothesis. Data is stationary

# %% [markdown]
# ### Trend & Seasonality Plot

# %%
decomposition = seasonal_decompose(stock_data,period=350,model="multiplicable")

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(stock_data, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %% [markdown]
# ### Plotting
# ### Auto Correlation Function (ACF)
# ### Partial Auto Correaltion Function (PACF)
# ### for p & q values

# %%
fig = plt.figure(figsize=(12, 25))  # Adjusting the figure size to fit both plots
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(stock_data_first_difference.dropna(inplace=False), lags=35, ax=ax1) 
ax1.set_title('Autocorrelation Function (ACF)')

ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(stock_data_first_difference.dropna(inplace=False), lags=35, ax=ax2) 
ax2.set_title('Partial Autocorrelation Function (PACF)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Splitting of Data in train & test

# %%
train_data = stock_data.iloc[:7447]
test_data = stock_data.iloc[7447:8180]
train_data
# Out:
#               Price
# Date
# 1990-01-02     7.27
# 1990-01-03     6.92
# 1990-01-04     6.50
# 1990-01-05     6.71
# 1990-01-08     6.71
# ...             ...
# 2020-12-24  1810.41
# 2020-12-28  1818.71
# 2020-12-29  1806.68
# 2020-12-30  1811.63
# 2020-12-31  1802.37
#
# [7447 rows x 1 columns]

# %%
test_data
# Out:
#               Price
# Date
# 2021-01-01  1804.37
# 2021-01-04  1807.41
# 2021-01-05  1784.94
# 2021-01-06  1737.87
# 2021-01-07  1735.05
# ...             ...
# 2023-12-11  2459.05
# 2023-12-12  2423.95
# 2023-12-13  2433.40
# 2023-12-14  2464.50
# 2023-12-15  2495.20
#
# [733 rows x 1 columns]

# %% [markdown]
# ### from First order Differencing we consider d=1 & from ACF & PACF plots we consider p=2,4 & q=1

# %% [markdown]
# ## Various ARIMA MODELs

# %% [markdown]
# ## ARIMA(2,1,1)

# %%
# Build Model
model_arima = ARIMA(train_data,order = (2,1,1))
model_arima = model_arima.fit()
model_arima.summary()
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 7447
# Model:                 ARIMA(2, 1, 1)   Log Likelihood              -27824.301
# Date:                Sun, 24 Dec 2023   AIC                          55656.602
# Time:                        12:20:58   BIC                          55684.263
# Sample:                             0   HQIC                         55666.104
#                                - 7447
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8575      0.026    -33.596      0.000      -0.908      -0.807
# ar.L2         -0.0114      0.004     -2.679      0.007      -0.020      -0.003
# ma.L1          0.8654      0.026     32.853      0.000       0.814       0.917
# sigma2       103.1004      0.371    277.597      0.000     102.372     103.828
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            594612.80
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             164.08   Skew:                             0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                        46.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start = len(train_data)
end = len(train_data)+len(test_data)-1
pred_arima = model_arima.predict(start=start,end=end)
pred_arima
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 7447    1802.603407
# 7448    1802.509189
# 7449    1802.587310
# 7450    1802.521400
# 7451    1802.577023
#            ...
# 8175    1802.551566
# 8176    1802.551566
# 8177    1802.551566
# 8178    1802.551566
# 8179    1802.551566
# Name: predicted_mean, Length: 733, dtype: float64

# %% [markdown]
# ### Evaluate the model's performance using metrics like RMSE, MAPE, ME, and MAE.

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    return({'mape':mape, 'me':me, 'mae': mae, 'rmse':rmse})

# %%
ns_arima_acc = forecast_accuracy(pred_arima.values, test_data.values)
ns_arima_acc
# Out:
# {'mape': 0.1743674462030721,
#  'me': -393.52175117932063,
#  'mae': 399.51977418042884,
#  'rmse': 446.92882533330936}

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, label='actual')
plt.plot(pred_arima, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training data')
plt.plot(test_data, label='Actual Stock Price')
plt.plot(pred_arima, label='Predicted Stock Price')
plt.title('Reliance Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Reliance Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# # ARIMA(4,1,3)

# %%
Model_arima = ARIMA(train_data,order = (4,1,3))
Model_arima = Model_arima.fit()
Model_arima.summary()
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 7447
# Model:                 ARIMA(4, 1, 3)   Log Likelihood              -27771.067
# Date:                Sun, 24 Dec 2023   AIC                          55558.134
# Time:                        12:22:21   BIC                          55613.457
# Sample:                             0   HQIC                         55577.138
#                                - 7447
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7608      0.022    -34.074      0.000      -0.805      -0.717
# ar.L2          0.6760      0.036     18.698      0.000       0.605       0.747
# ar.L3          0.9151      0.018     50.336      0.000       0.879       0.951
# ar.L4         -0.0284      0.005     -6.028      0.000      -0.038      -0.019
# ma.L1          0.7835      0.022     35.830      0.000       0.741       0.826
# ma.L2         -0.6411      0.038    -17.061      0.000      -0.715      -0.567
# ma.L3         -0.9107      0.021    -43.292      0.000      -0.952      -0.870
# sigma2       100.6814      0.373    269.850      0.000      99.950     101.413
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):            568640.85
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):             160.43   Skew:                             0.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                        45.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
start = len(train_data)
end = len(train_data)+len(test_data)-1
Pred_arima = Model_arima.predict(start=start,end=end)
print(Pred_arima)
# Out:
# 7447    1808.417414
# 7448    1800.850603
# 7449    1807.807732
# 7450    1803.196476
# 7451    1804.311580
#            ...
# 8175    1804.748326
# 8176    1804.609538
# 8177    1804.715345
# 8178    1804.668911
# 8179    1804.644878
# Name: predicted_mean, Length: 733, dtype: float64
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
Ns_arima_acc = forecast_accuracy(Pred_arima.values, test_data.values)
Ns_arima_acc
# Out:
# {'mape': 0.17354908424390966,
#  'me': -391.39498519055866,
#  'mae': 397.67379910635384,
#  'rmse': 445.05845037580974}

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, label='actual')
plt.plot(Pred_arima, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ## Smoothing Technique Methods

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %% [markdown]
# ### Additional Models and Comparison

# %% [markdown]
# ## Simple Exponential Smoothing

# %%
SES = SimpleExpSmoothing(train_data).fit(smoothing_level = 0.2)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)

# %%
pred_ses = SES.predict(start = len(train_data),end = len(train_data)+len(test_data)-1)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
ns_ses_acc = forecast_accuracy(pred_ses.values,test_data.values)
ns_ses_acc
# Out:
# {'mape': 0.17526847267465112,
#  'me': -395.83360783118087,
#  'mae': 401.5470291751085,
#  'rmse': 448.9657574237152}

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, label='actual')
plt.plot(pred_ses, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ## Holt's Method

# %%
HLT= Holt(train_data).fit(smoothing_level=0.8, smoothing_slope=0.2)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)

# %%
pred_holt = HLT.predict(start = len(train_data),end = len(train_data)+len(test_data)-1)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
ns_hlt_acc = forecast_accuracy(pred_holt.values,test_data.values)
ns_hlt_acc
# Out:
# {'mape': 0.1256455323567054,
#  'me': 36.81819347927565,
#  'mae': 267.55032777558574,
#  'rmse': 327.3049312329997}

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, label='actual')
plt.plot(pred_holt, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ## Holt-Winter Method

# %%
HLW = ExponentialSmoothing(train_data,seasonal='add',trend='add',seasonal_periods=2).fit()
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
pred_hlw=HLW.predict(start = len(train_data),end = len(train_data)+len(test_data)-1)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred_hlw
# Out:
# 7447    1803.031602
# 7448    1803.814115
# 7449    1804.475544
# 7450    1805.258057
# 7451    1805.919486
#            ...
# 8175    2328.626408
# 8176    2329.408922
# 8177    2330.070350
# 8178    2330.852863
# 8179    2331.514292
# Length: 733, dtype: float64

# %%
ns_hlw_acc = forecast_accuracy(pred_hlw.values,test_data.values)
ns_hlw_acc
# Out:
# {'mape': 0.10932337165715947,
#  'me': -128.7701791721573,
#  'mae': 241.4461385987821,
#  'rmse': 291.21444647905423}

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, label='actual')
plt.plot(pred_hlw, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ## Modelwise Evaluation

# %% [markdown]
# ### Model Sorted by the RMSE values

# %%
data = {"MODEL":pd.Series(["ARIMA(2,1,1)","ARIMA(4,1,3)","Simple exponential smoothing","Holt Method","Holt-Winter Method"]),
"RMSE_values":pd.Series([ns_arima_acc["rmse"],Ns_arima_acc["rmse"],ns_ses_acc["rmse"],ns_hlt_acc["rmse"],ns_hlw_acc["rmse"]]),
"MAPE_values":pd.Series([ns_arima_acc["mape"],Ns_arima_acc["mape"],ns_ses_acc["mape"],ns_hlt_acc["mape"],ns_hlw_acc["mape"]]),
"ME_values":pd.Series([ns_arima_acc["me"],Ns_arima_acc["me"],ns_ses_acc["me"],ns_hlt_acc["me"],ns_hlw_acc["me"]]),
"MAE_values":pd.Series([ns_arima_acc["mae"],Ns_arima_acc["mae"],ns_ses_acc["mae"],ns_hlt_acc["mae"],ns_hlw_acc["mae"]])}

table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_values'])
# Out:
#                           MODEL  RMSE_values  MAPE_values   ME_values  \
# 4            Holt-Winter Method   291.214446     0.109323 -128.770179
# 3                   Holt Method   327.304931     0.125646   36.818193
# 1                  ARIMA(4,1,3)   445.058450     0.173549 -391.394985
# 0                  ARIMA(2,1,1)   446.928825     0.174367 -393.521751
# 2  Simple exponential smoothing   448.965757     0.175268 -395.833608
#
#    MAE_values
# 4  241.446139
# 3  267.550328
# 1  397.673799
# 0  399.519774
# 2  401.547029

# %% [markdown]
# ### Model Sorted by the MAPE values

# %%
tata = {"MODEL":pd.Series(["ARIMA(2,1,1)","ARIMA(4,1,3)","Simple exponential smoothing","Holt Method","Holt-Winter Method"]),
"RMSE_values":pd.Series([ns_arima_acc["rmse"],Ns_arima_acc["rmse"],ns_ses_acc["rmse"],ns_hlt_acc["rmse"],ns_hlw_acc["rmse"]]),
"MAPE_values":pd.Series([ns_arima_acc["mape"],Ns_arima_acc["mape"],ns_ses_acc["mape"],ns_hlt_acc["mape"],ns_hlw_acc["mape"]]),
"ME_values":pd.Series([ns_arima_acc["me"],Ns_arima_acc["me"],ns_ses_acc["me"],ns_hlt_acc["me"],ns_hlw_acc["me"]]),
"MAE_values":pd.Series([ns_arima_acc["mae"],Ns_arima_acc["mae"],ns_ses_acc["mae"],ns_hlt_acc["mae"],ns_hlw_acc["mae"]])}

table_mape=pd.DataFrame(tata)
table_mape.sort_values(['MAPE_values'])
# Out:
#                           MODEL  RMSE_values  MAPE_values   ME_values  \
# 4            Holt-Winter Method   291.214446     0.109323 -128.770179
# 3                   Holt Method   327.304931     0.125646   36.818193
# 1                  ARIMA(4,1,3)   445.058450     0.173549 -391.394985
# 0                  ARIMA(2,1,1)   446.928825     0.174367 -393.521751
# 2  Simple exponential smoothing   448.965757     0.175268 -395.833608
#
#    MAE_values
# 4  241.446139
# 3  267.550328
# 1  397.673799
# 0  399.519774
# 2  401.547029

# %% [markdown]
# ## Final Model Selection

# %%
HLW = ExponentialSmoothing(stock_data,seasonal='add',trend='add',seasonal_periods=2).fit()
final_model = HLW
final_model.summary()
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    Price   No. Observations:                 8180
# Model:             ExponentialSmoothing   SSE                        1545357.243
# Optimized:                         True   AIC                          42885.983
# Trend:                         Additive   BIC                          42928.040
# Seasonal:                      Additive   AICC                         42886.001
# Seasonal Periods:                     2   Date:                 Sun, 24 Dec 2023
# Box-Cox:                          False   Time:                         12:24:54
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.9948693                alpha                 True
# smoothing_trend               0.0002051                 beta                 True
# smoothing_seasonal            0.0001031                gamma                 True
# initial_level                 6.7919094                  l.0                 True
# initial_trend                 0.1857301                  b.0                 True
# initial_seasons.0             0.0749046                  s.0                 True
# initial_seasons.1            -0.0748228                  s.1                 True
# ---------------------------------------------------------------------------------
# """

# %% [markdown]
# ### Forecasting Beyond Available Data for next 1 year

# %%
future_stock_price=final_model.forecast(steps= 360)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
#future_df

# %%
future_stock_price.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 360 entries, 8180 to 8539
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 360 non-null    float64
# dtypes: float64(1)
# memory usage: 2.9 KB

# %% [markdown]
# ### Plot of Stock data Actual value with Forcasted value for next 1 year

# %%
plt.figure(figsize=(12, 5), dpi=100)
plt.plot(stock_data, label='original')
plt.plot(future_stock_price, label='forecast')
plt.title('Forecast')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
#model =future_stock_price

# %%
import pickle

# %%
# Load the model from the file
with open('Reliance_Stock.pkl', 'wb') as file:
    pickle.dump(future_stock_price, file)

# %%
final_model.forecast(steps=50)
# Out:
# /home/sunbeam/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 8180    2495.636181
# 8181    2495.882169
# 8182    2496.475421
# 8183    2496.721410
# 8184    2497.314661
# 8185    2497.560650
# 8186    2498.153901
# 8187    2498.399890
# 8188    2498.993141
# 8189    2499.239130
# 8190    2499.832381
# 8191    2500.078370
# 8192    2500.671621
# 8193    2500.917610
# 8194    2501.510861
# 8195    2501.756850
# 8196    2502.350102
# 8197    2502.596090
# 8198    2503.189342
# 8199    2503.435331
# 8200    2504.028582
# 8201    2504.274571
# 8202    2504.867822
# 8203    2505.113811
# 8204    2505.707062
# 8205    2505.953051
# 8206    2506.546302
# 8207    2506.792291
# 8208    2507.385542
# 8209    2507.631531
# 8210    2508.224782
# 8211    2508.470771
# 8212    2509.064023
# 8213    2509.310011
# 8214    2509.903263
# 8215    2510.149251
# 8216    2510.742503
# 8217    2510.988492
# 8218    2511.581743
# 8219    2511.827732
# 8220    2512.420983
# 8221    2512.666972
# 8222    2513.260223
# 8223    2513.506212
# 8224    2514.099463
# 8225    2514.345452
# 8226    2514.938703
# 8227    2515.184692
# 8228    2515.777943
# 8229    2516.023932
# dtype: float64
