# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
stock_data = pd.read_csv('data.csv')
stock_data
# Out:
#             Date    Open     High      Low    Close  Volume  OpenInt
# 0     2010-07-21  24.333  24.3330  23.9460  23.9460   43321        0
# 1     2010-07-22  24.644  24.6440  24.3620  24.4870   18031        0
# 2     2010-07-23  24.759  24.7590  24.3140  24.5070    8897        0
# 3     2010-07-26  24.624  24.6240  24.4490  24.5950   19443        0
# 4     2010-07-27  24.477  24.5170  24.4310  24.5170    8456        0
# ...          ...     ...      ...      ...      ...     ...      ...
# 1560  2017-11-06  57.610  57.7372  57.2285  57.6500   41601        0
# 1561  2017-11-07  57.290  57.3460  57.1446  57.2850   50935        0
# 1562  2017-11-08  57.310  57.5500  57.2200  57.4900   71770        0
# 1563  2017-11-09  57.230  57.2300  56.7100  56.9265   53130        0
# 1564  2017-11-10  56.960  56.9600  56.3909  56.4000   29233        0
#
# [1565 rows x 7 columns]

# %%
stock_data.set_index(pd.to_datetime(stock_data['Date']))
# Out:
#                   Date    Open     High      Low    Close  Volume  OpenInt
# Date
# 2010-07-21  2010-07-21  24.333  24.3330  23.9460  23.9460   43321        0
# 2010-07-22  2010-07-22  24.644  24.6440  24.3620  24.4870   18031        0
# 2010-07-23  2010-07-23  24.759  24.7590  24.3140  24.5070    8897        0
# 2010-07-26  2010-07-26  24.624  24.6240  24.4490  24.5950   19443        0
# 2010-07-27  2010-07-27  24.477  24.5170  24.4310  24.5170    8456        0
# ...                ...     ...      ...      ...      ...     ...      ...
# 2017-11-06  2017-11-06  57.610  57.7372  57.2285  57.6500   41601        0
# 2017-11-07  2017-11-07  57.290  57.3460  57.1446  57.2850   50935        0
# 2017-11-08  2017-11-08  57.310  57.5500  57.2200  57.4900   71770        0
# 2017-11-09  2017-11-09  57.230  57.2300  56.7100  56.9265   53130        0
# 2017-11-10  2017-11-10  56.960  56.9600  56.3909  56.4000   29233        0
#
# [1565 rows x 7 columns]

# %%
#plot close price
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close Prices')
plt.plot(stock_data['Close'])
plt.title('ARCH CAPITAL GROUP closing price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #plot close price
# ----> 2 plt.figure(figsize=(10,6))
#       3 plt.grid(True)
#       4 plt.xlabel('Date')
#
# NameError: name 'plt' is not defined

# %%
#Distribution of the dataset
df_close = stock_data['Close']
df_close.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
result = seasonal_decompose(df_close, model='multiplicative', period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %%
#if not stationary then eliminate trend
#Eliminate trend
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df_close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#split data into train and training set
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-8340.599, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-8346.009, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-8347.140, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8340.711, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-8363.141, Time=0.56 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-8361.521, Time=0.55 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-8361.153, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-8352.756, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=-8349.455, Time=0.16 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-8358.580, Time=0.50 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 2.692 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1405
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                4185.570
# Date:                Wed, 29 Nov 2023   AIC                          -8363.141
# Time:                        04:23:36   BIC                          -8342.152
# Sample:                             0   HQIC                         -8355.296
#                                - 1405
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0001   7.95e-05      1.580      0.114   -3.03e-05       0.000
# ar.L1          0.7110      0.066     10.846      0.000       0.582       0.839
# ma.L1         -0.8080      0.056    -14.513      0.000      -0.917      -0.699
# sigma2         0.0002   3.44e-06     43.786      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):               970.93
# Prob(Q):                              0.75   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.68   Skew:                            -0.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Build Model
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(train_data, order=(1,1,2))  
fitted = model.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1405
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                4183.559
# Date:                Wed, 29 Nov 2023   AIC                          -8359.119
# Time:                        04:27:42   BIC                          -8338.131
# Sample:                             0   HQIC                         -8351.274
#                                - 1405
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6986      0.098      7.130      0.000       0.507       0.891
# ma.L1         -0.7857      0.100     -7.870      0.000      -0.981      -0.590
# ma.L2         -0.0059      0.028     -0.213      0.831      -0.060       0.048
# sigma2         0.0002   3.47e-06     43.574      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               946.96
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.68   Skew:                            -0.59
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast
return_value = fitted.forecast(321, alpha=0.05)  # 95% conf

# %%
return_value
# Out:
# 1408    3.839608
# 1409    3.838807
# 1410    3.838248
# 1411    3.837858
# 1412    3.837585
#           ...
# 1724    3.836953
# 1725    3.836953
# 1726    3.836953
# 1727    3.836953
# 1728    3.836953
# Name: predicted_mean, Length: 321, dtype: float64

# %%
# Make a pandas series
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training data')
plt.plot(test_data, color = 'blue', label='Actual Stock Price')
plt.plot(fc_series, color = 'orange',label='Predicted Stock Price')
plt.title('ARCH CAPITAL GROUP Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('ARCH CAPITAL GROUP Stock Price')
plt.legend(loc='upper left', fontsize=8)
plt.show()
